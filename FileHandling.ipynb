# %% [markdown]
# Files, exceptional handling, logging and
# memory management Questions

# %% [markdown]
# 1 What is the difference between interpreted and compiled languages?
# - Interpreted: Code is executed line-by-line (e.g., Python, JavaScript).
# - Compiled: Code is translated into machine code before execution (e.g., C, C++).
#
# 2 What is exception handling in Python
# - Allows you to gracefully handle errors. Uses try, except, finally, and else blocks to manage exceptions
#
# 3 What is the purpose of the finally block in exception handling?
# - Executes no matter what—whether an exception is raised or not. Often used for cleanup actions like closing files or releasing resources.
#
# 4 What is logging in Python
# - A way to track events that happen when software runs. Helps in debugging, monitoring, and error tracking.
#
# 5 What is the significance of the __del__ method in Python?
# - Acts as a destructor, called when an object is deleted. Used to clean up resources (not commonly used due to garbage collection).
#
#
# 6 What is the difference between import and from ... import in Python?
# - import module: Imports entire module; access with module.name , from module import name: Imports only specific attribute.
#
# 7 How can you handle multiple exceptions in Python
# - except (TypeError, ValueError) as e:
#
# 8 What is the purpose of the with statement when handling files in Python?
# - Automatically closes the file after the block is exited.
#
# 9 What is the difference between multithreading and multiprocessing?
# - Multithreading: Multiple threads within one process; shares memory; best for I/O-bound tasks.
# - Multiprocessing: Multiple processes; separate memory; best for CPU-bound tasks.
#
#
# 10 What are the advantages of using logging in a program?
# - Persistent logs, helps in troubleshooting and monitoring, more flexible than print().
#
# 11 What is memory management in Python?
# - Handled via reference counting and garbage collection.
#
# 12 What are the basic steps involved in exception handling in Python?
# - Try block runs. If an error occurs, it's caught in the except.
# else runs if no error. finally runs regardless.
#
# 13 Why is memory management important in Python?
# - Prevents memory leaks, Ensures efficient usage of available memory.
#
# 14 What is the role of try and except in exception handling?
# - try: Code that might throw an error. Except: Block to handle the error gracefully.
#
# 15 How does Python's garbage collection system work?
# - Automatically reclaims memory. Uses reference counting + cyclic garbage collector.
#
# 16 What is the purpose of the else block in exception handling?
# - Executes if no exception was raised in the try block.
#
# 17 What are the common logging levels in Python?
# - DEBUG, INFO, WARNING, ERROR, CRITICAL
#
# 18 What is the difference between os.fork() and multiprocessing in Python?
# - os.fork(): Unix-only, lower-level process creation. multiprocessing: Cross-platform, higher-level API.
#
# 19 What is the importance of closing a file in Python?
# - Prevents resource leaks, Ensures data is properly written and file is not corrupted.
#
# 20 What is the difference between file.read() and file.readline() in Python?
# - read(): Reads entire file.
# - readline(): Reads one line at a time.
#
# 21 What is the logging module in Python used for?
# - Built-in module to record log messages in a structured way.
#
# 22 What is the os module in Python used for in file handling?
# - Used to interact with the operating system: file paths, environment, directories.
#
# 23 What are the challenges associated with memory management in Python?
# - Circular references, memory leaks, handling large datasets.
#
# 24 How do you raise an exception manually in Python?
# - raise ValueError("Invalid input")
#
# 25 Why is it important to use multithreading in certain applications?
# - Useful for I/O-bound tasks like network calls, file access.- - - Makes programs more responsive.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#1
file = open("file.txt" , 'w')
file.write("some string on file\n this is second line")
file.close()

# %%
#2
with open("file.txt", "r") as file:
    print(file.read())
# Out:
# some string on file
#  this is second line

# %%
#3
try:
  f = open("example.txt", 'r')
except FileNotFoundError as e:
  print("file do not exist",e)
# Out:
# file do not exist [Errno 2] No such file or directory: 'example.txt'

# %%
#4
import shutil
destifile = open("file2.txt",'w')
shutil.move("file.txt","file2.txt")
with open("file2.txt", "r") as file:
    print(file.read())
# Out:
# some string on file
#  this is second line

# %%
#5
try:
  print(9/0)
except ZeroDivisionError as e:
  print("division by zero gives error",e)
# Out:
# division by zero gives error division by zero

# %%
#6
import logging
logging.basicConfig(filename="text.log", level=logging.ERROR)
try:
  print(9/0)
except ZeroDivisionError as e:
  logging.error("this is zero div %s", e)
  print("division by zero gives error",e)
# Out:
# ERROR:root:this is zero div division by zero
# division by zero gives error division by zero

# %%
#7
import logging
logging.basicConfig(filename="text.log", level=logging.DEBUG, format = '%(asctime)s %(message)s')
logging.debug("This msg is for debugging")
logging.info("This is my info msg")
logging.warning("This is my warning msg")
logging.shutdown()
# Out:
# WARNING:root:This is my warning msg

# %%
#8
try:
  open("fssf.txt",'r')
except FileNotFoundError as e:
    print("file cannot be opened",e)
# Out:
# file cannot be opened [Errno 2] No such file or directory: 'fssf.txt'

# %%
#9
file = open("file.txt" , 'w')
file.write("some string on file\n this is second line")
file.close()

with open("file.txt", "r") as file:
  print(file.readlines())
# Out:
# ['some string on file\n', ' this is second line']

# %%
#10
with open("file.txt",'a') as f:
  f.write("\n this is another line")

with open("file.txt", "r") as file:
    print(file.read())
# Out:
# some string on file
#  this is second linethis is another line
# this is another line
# this is another line
# this is another line
#  this is another line

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#11

d = {"1": "Aj", "2":"B", "3":"C"}
try:
  d["4"]

except KeyError as e:
  print("No such key in dictionary",e)
# Out:
# No such key in dictionary '4'

# %%
#12

try:
  a = 10/0
  print(a)
  print(10/"strr")

except ZeroDivisionError as e:
  print("this is a zero division error",e)

except TypeError as e:
  print("some error",e)
# Out:
# this is a zero division error division by zero

# %%
#13
try:
  open('filess.txt','r')

except FileNotFoundError as e:
  print("file does not exist",e)
# Out:
# file does not exist [Errno 2] No such file or directory: 'filess.txt'

# %%
#14
import logging
logging.basicConfig(filename= "testlogger.log", level = logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')

logging.info("this is an information")
logging.error("this is an error")
# Out:
# ERROR:root:this is an error

# %%
#15

file = open("file.txt" , 'w')
file.write("some string on file\n this is second line")
file.close()
file = open("file2.txt" , 'w')

try:
  with open("file.txt", "r") as file:
      print(file.readlines())
  with open("file2.txt","r") as file:
        content2 = file.readlines()
        if not content2:
            raise ValueError("file2.txt is empty")
        print("file2.txt contents:", content2)

except Exception as e:
    print(" file error:", e)
# Out:
# ['some string on file\n', ' this is second line']
#  file error: file2.txt is empty

# %%
#16
# !pip install -q memory-profiler

from memory_profiler import profile

@profile
def small_memory_function():
    a = [i for i in range(1000)]  # Small memory allocation
    b = sum(a)
    return b

if __name__ == "__main__":
    small_memory_function()
# Out:
# PYDEV DEBUGGER WARNING:
# sys.settrace() should not be used when the debugger is being used.
# This may cause the debugger to stop working correctly.
# If this is needed, please check:
# http://pydev.blogspot.com/2007/06/why-cant-pydev-debugger-work-with.html
# to see how to restore the debug tracing back correctly.
# Call Location:
#   File "/usr/local/lib/python3.11/dist-packages/memory_profiler.py", line 847, in enable
#     sys.settrace(self.trace_memory_usage)
#
#
# PYDEV DEBUGGER WARNING:
# sys.settrace() should not be used when the debugger is being used.
# This may cause the debugger to stop working correctly.
# If this is needed, please check:
# http://pydev.blogspot.com/2007/06/why-cant-pydev-debugger-work-with.html
# to see how to restore the debug tracing back correctly.
# Call Location:
#   File "/usr/local/lib/python3.11/dist-packages/memory_profiler.py", line 850, in disable
#     sys.settrace(self._original_trace_function)
# ...

# %%
#17
# Open the file 'filenum.txt' in write mode
with open("filenum.txt", 'w') as file:
    for i in range(1, 10):
        file.write(str(i) + '\n')

with open("filenum.txt", "r") as file:
      print(file.read())
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
#18
import logging
from logging.handlers import RotatingFileHandler

# Set up the logging configuration
log_filename = "app.log"

# Create a rotating file handler that logs into "app.log" with a maximum size of 1MB and keeps 5 backup files
handler = RotatingFileHandler(log_filename, maxBytes=1_000_000, backupCount=5)

# Set the logging level (DEBUG, INFO, WARNING, ERROR, CRITICAL)
handler.setLevel(logging.DEBUG)

# Create a logging format
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)

# Set up the logger
logger = logging.getLogger('MyLogger')
logger.setLevel(logging.DEBUG)

# Add the rotating handler to the logger
logger.addHandler(handler)

# Example log messages
logger.debug("This is a debug message.")
logger.info("This is an info message.")
logger.warning("This is a warning message.")
logger.error("This is an error message.")
logger.critical("This is a critical message.")
# Out:
# DEBUG:MyLogger:This is a debug message.
# INFO:MyLogger:This is an info message.
# WARNING:MyLogger:This is a warning message.
# ERROR:MyLogger:This is an error message.
# CRITICAL:MyLogger:This is a critical message.

# %%
#19

try:
  d = {'a':'2', 'b':'8'}
  d['dd']
  a = [1,2,3]
  print(a[7])

except (IndexError, KeyError) as e:
  print("some error",e)
# Out:
# some error 'dd'

# %%
#20
with open("filet.txt",'w') as f:
    f.write("this is the daily work the e need to complete the")

with open("filet.txt", 'r') as file:
    content = file.read()  # Read the entire content of the file
    print(content)
# Out:
# this is the daily work the e need to complete the

# %%
#21

with open("filete.txt",'w') as f:
    f.write("this is the daily work the e need to complete the")

chr = "the"
count =0
with open("filete.txt", 'r') as file:
  ch = file.read()
  count = ch.split().count(chr)

print(count)
# Out:
# 3

# %%
#22

file = open("file2.txt" , 'w')

try:
  with open("file2.txt","r") as file:
        content2 = file.readlines()
        if not content2:
            raise ValueError("file2.txt is empty")
        print("file2.txt contents:", content2)

except Exception as e:
    print(" file error:", e)
# Out:
#  file error: file2.txt is empty

# %%
#23
import logging
logging.basicConfig(filename= "testlogger.log", level = logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')
try:
  with open("filese.txt",'r') as f:
    print(file.read())

except:
  logging.error("this file does not exist")
# Out:
# ERROR:root:this file does not exist
